# %%
from scipy import stats;
import matplotlib.pyplot as plt;

# %%
fig = plt.figure();
ax1 = fig.add_subplot(211);
#211 .. rows, ncols, and index
x = stats.loggamma.rvs(5, size=500)+5;
#get data from loggama function which is a pereto/ powerlaw funtion
prob = stats.probplot(x, dist=stats.norm, plot=ax1)
#q-q plot it against norm dist
ax1.set_label('')
ax1.set_title('Probplot against normal distribution')
# Out:
# Text(0.5, 1.0, 'Probplot against normal distribution')

# %%
add_subplotfig = plt.figure();
ax2 = fig.(212)
xt, _ = stats.boxcox(x)
prob = stats.probplot(xt, dist=stats.norm, plot=ax2)
ax2.set_title('Probplot after Box-Cox transformation')
# Out:
# Text(0.5, 1.0, 'Probplot after Box-Cox transformation')

# %%
plt.show()
