# %%
import numpy as np;
import pylab;
import scipy.stats as stats

measurements = np.random.normal(loc=20,scale=5,size=100) #generate a gaussian dist with mean 20 and variance 5
stats.probplot(measurements,dist="norm",plot=pylab)
pylab.show()
