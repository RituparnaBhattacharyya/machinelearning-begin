# %%
#import required libraries 
#import OpenCV library
import cv2
#import matplotlib library
import matplotlib.pyplot as plt
#importing time library for speed comparisons of both classifiers
import time 
# %matplotlib inline

# %%
def detect_faces(f_cascade, colored_img, scaleFactor = 1.1):
 #just making a copy of image passed, so that passed image is not changed 
 img_copy = colored_img.copy()          
 
 #convert the test image to gray image as opencv face detector expects gray images
 gray = cv2.cvtColor(img_copy, cv2.COLOR_BGR2GRAY)     

 plt.imshow(gray, cmap='gray');
    
 #let's detect multiscale (some images may be closer to camera than others) images
 faces = f_cascade.detectMultiScale(gray, scaleFactor=scaleFactor, minNeighbors=5);
    
 print('Faces found: ', len(faces))
 
 #go over list of faces and draw them as rectangles on original colored img
 for (x, y, w, h) in faces:
      cv2.rectangle(img_copy, (x, y), (x+w, y+h), (0, 255, 0), 2)              
 
 return img_copy

# %%
def convertToRGB(img): 
    return cv2.cvtColor(img, cv2.COLOR_BGR2RGB);

#load cascade classifier training file for haarcascade 
test1 = cv2.imread('detection/images/me.jpeg')
lbpcascade_frontalface = cv2.CascadeClassifier('detection/data/lbpcascade_frontalface_improved.xml');
#detect_faces(haar_face_cascade, test1, 1.1);
plt.imshow(convertToRGB(detect_faces(lbpcascade_frontalface, test1, 1.1)));
# Out:
# Faces found:  1

# %%
haar_face_cascade = cv2.CascadeClassifier('detection/data/haarcascade_frontalface_alt.xml');
plt.imshow(convertToRGB(detect_faces(haar_face_cascade, test1, 1.1)));
# Out:
# Faces found:  1

# %%
test1 = cv2.imread('detection/images/me1.jpeg')
lbpcascade_frontalface = cv2.CascadeClassifier('detection/data/haarcascade_frontalface_alt.xml');
#detect_faces(haar_face_cascade, test1, 1.1);
plt.imshow(convertToRGB(detect_faces(lbpcascade_frontalface, test1, 1.1)));
# Out:
# Faces found:  1

# %%
test1 = cv2.imread('detection/images/me2.jpeg')
lbpcascade_frontalface = cv2.CascadeClassifier('detection/data/haarcascade_frontalface_alt.xml');
#detect_faces(haar_face_cascade, test1, 1.1);
plt.imshow(convertToRGB(detect_faces(lbpcascade_frontalface, test1, 1.1)));
# Out:
# Faces found:  1

# %%
#load cascade classifier training file for haarcascade 
test1 = cv2.imread('detection/images/me1.jpeg')
lbpcascade_frontalface = cv2.CascadeClassifier('detection/data/lbpcascade_frontalface_improved.xml');
#detect_faces(haar_face_cascade, test1, 1.1);
plt.imshow(convertToRGB(detect_faces(lbpcascade_frontalface, test1, 1.1)));
# Out:
# Faces found:  1

# %%
#load cascade classifier training file for haarcascade 
test1 = cv2.imread('detection/images/me2.jpeg')
lbpcascade_frontalface = cv2.CascadeClassifier('detection/data/lbpcascade_frontalface_improved.xml');
#detect_faces(haar_face_cascade, test1, 1.1);
plt.imshow(convertToRGB(detect_faces(lbpcascade_frontalface, test1, 1.1)));
# Out:
# Faces found:  1
